# %%
txt="Hello, Welcome to My World"
print(txt)
# Out:
# Hello, Welcome to My World

# %%
x=txt.lower()
print(x)
# Out:
# hello, welcome to my world

# %%
y=txt.casefold()
print(y)
# Out:
# hello, welcome to my world
